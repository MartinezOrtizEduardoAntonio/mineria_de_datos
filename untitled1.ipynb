# %% [markdown]
# <a href="https://colab.research.google.com/github/MartinezOrtizEduardoAntonio/mineria_de_datos/blob/main/untitled1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Mineria de Datos

# %% [markdown]
# ##primer Parcial
# ##Introduccion
# ##conceptos Ciencia de Datos:
# La Ciencia de Datos es un campo multidisciplinario que combina estadística, matemáticas, inteligencia artificial y computación para analizar grandes volúmenes de datos (Big Data) y extraer conocimiento significativo, patrones y tendencias, con el fin de apoyar la toma de decisiones, hacer predicciones y resolver problemas en diversas industrias. Implica todo el ciclo de vida de los datos, desde su recolección y limpieza hasta su análisis mediante técnicas como el Aprendizaje Automático (Machine Learning) y la visualización para generar información útil y estratégica.
#
# Mineria de Datos: La minería de datos (o data mining) es el proceso de analizar grandes volúmenes de datos para descubrir patrones, anomalías y correlaciones ocultas, transformando datos brutos en conocimiento útil para predecir comportamientos, tomar decisiones estratégicas y resolver problemas de negocio, combinando técnicas de estadística, IA y aprendizaje automático para encontrar tendencias no evidentes a simple vista.

# %% [markdown]
# # Fundamentos de Python para Ciencia de Datos > *Un recorrido inspirado en el "Python Data Science Handbook" de Jake VanderPlas.*
# ---
# ## Introducción Python se ha consolidado como la herramienta por excelencia para el análisis de datos debido a su sintaxis limpia y su ecosistema robusto. En este cuaderno, exploraremos los pilares fundamentales que permiten a un científico de datos pasar de la simple ejecución de scripts a la construcción de modelos complejos.
# ![](https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcQA58mH1EAjc2uEChw2pMg-Lkm9iUhR1U6Fbw&s)
# ---

# %% [markdown]
# ## 1. La Flexibilidad de Python: Tipado Dinámico A diferencia de lenguajes como C++ o Java, donde cada variable debe ser declarada con un tipo específico, Python utiliza **tipado dinámico**. Como señala VanderPlas, en Python las variables son más que simples contenedores; son punteros a objetos en memoria que contienen metadatos sobre su tipo y valor.

# %%
# En Python, podemos reasignar una variable a diferentes tipos de datos
x = 4          # x es un entero
print(f"Valor inicial (int): {x}")

x = "Hola Mundo" # Ahora x es una cadena de texto
print(f"Valor cambiado (str): {x}")

x = [1, 2, 3]  # Ahora x es una lista
print(f"Valor como objeto (list): {x}")

# %% [markdown]
# ## 2. Estructuras de Datos Integradas El manejo eficiente de colecciones es vital. Las listas y los diccionarios son los bloques de construcción sobre los cuales se sostienen librerías más avanzadas como Pandas.
#
# **Listas:** Colecciones ordenadas y mutables.
#
# **Diccionarios:** Mapas de llave-valor extremadamente rápidos para búsqueda de información.

# %%
# Creación de una lista de Python (heterogénea)
mi_lista = [1, "Python", 3.14, True]

# Acceso y manipulación
print(f"Elemento en índice 1: {mi_lista[1]}")

# Diccionarios: La base de la organización de datos
usuario = {
    "nombre": "Científico de Datos",
    "herramienta": "Jupyter/Colab",
    "lenguaje": "Python"
}

print(f"El usuario prefiere: {usuario['lenguaje']}")

# %% [markdown]
# ## 3. Control de Flujo y Legibilidad La elegancia de Python reside en su uso de la indentación. Aquí vemos cómo las estructuras foreif permiten iterar sobre datos de manera semántica y clara.

# %%
# List Comprehension: Una forma elegante de crear listas (muy recomendada en el libro)
cuadrados = [n ** 2 for n in range(10)]

print("Lista de cuadrados generada:")
print(cuadrados)

# Estructura condicional
valor = 15
if valor > 10:
    print(f"El valor {valor} es considerado alto para este análisis.")
else:
    print("El valor es normal.")

# %% [markdown]
# #IPython Magic Commands

# %% [markdown]
# #Understanding Data Types in Python

# %% [markdown]
# ## 4. Hacia el Análisis de Datos Real Aunque Python puro es potente, la verdadera magia del *Data Science Handbook* comienza con el "Stack Científico":
#
# **NumPy:** Para computación numérica eficiente.
#
# **Pandas:** Para manipulación de datos estructurados.
#
# **Matplotlib:** Para visualización profesional.

# %%
import numpy as np

# %%
import numpy as np
np.random.seed(0)

def compute_reciprocals(values):
    output = np.empty(len(values))
    for i in range(len(values)):
        output[i] = 1.0 / values[i]
    return output

values = np.random.randint(1, 10, size=5)
compute_reciprocals(values)

# %%
x = np.array([3 - 4j, 4 - 3j, 2 + 0j, 0 + 1j])
np.abs(x)

# %%
x = [1, 2, 3]
print("x     =", x)
print("e^x   =", np.exp(x))
print("2^x   =", np.exp2(x))
print("3^x   =", np.power(3, x))

# %%
import matplotlib.pyplot as plt
import numpy as np

# Generamos datos elegantes usando NumPy
x = np.linspace(0, 10, 100)
y = np.sin(x)

# Creamos un gráfico profesional
plt.figure(figsize=(8, 4))
plt.plot(x, y, label='Seno(x)', color='#2c3e50', linewidth=2)
plt.title('Visualización de Funciones Trigonométricas', fontsize=14)
plt.xlabel('Eje X', fontsize=12)
plt.ylabel('Eje Y', fontsize=12)
plt.grid(True, linestyle='--', alpha=0.6)
plt.legend()
plt.show()

# %%
#Esta funcion sirve para evaluar el desempeño en cuanto a tiempo
# %timeit L = [n ** 2 for n in range(1000)]
print(L)

# %%
L = []
for n in range(1000):
  L.append(n ** 2)
print(L)

# %%
def donothing(x):
  return x

# %%
def square(x):
    """square a number"""
    return x ** 2

for N in range(1, 4):
    print(N, "squared is", square(N))

# %% [markdown]
# The relative sluggishness of Python generally manifests itself in situations where many small operations are being repeated – for instance looping over arrays to operate on each element. For example, imagine we have an array of values and we'd like to compute the reciprocal of each. A straightforward approach might look like this:

# %%
import numpy as np
np.random.seed(0)

def compute_reciprocals(values):
    output = np.empty(len(values))
    for i in range(len(values)):
        output[i] = 1.0 / values[i]
    return output

values = np.random.randint(1, 10, size=5)
compute_reciprocals(values)

# %%
x = np.arange(1, 6)
np.multiply.outer(x, x)

# %% [markdown]
# ##Computation on Arrays: Broadcasting
# We saw in the previous section how NumPy's universal functions can be used to vectorize operations and thereby remove slow Python loops. Another means of vectorizing operations is to use NumPy's broadcasting functionality. Broadcasting is simply a set of rules for applying binary ufuncs (e.g., addition, subtraction, multiplication, etc.) on arrays of different sizes.

# %%
import numpy as np
a = np.array([0, 1, 2])
b = np.array([5, 5, 5])
print(a + b)

# %%
a = np.arange(3)
b = np.arange(3)[:, np.newaxis]

print(a)
print(b)

# %% [markdown]
# Just as before we stretched or broadcasted one value to match the shape of the other, here we've stretched both a and b to match a common shape, and the result is a two-dimensional array! The geometry of these examples is visualized in the following figure (Code to produce this plot can be found in the appendix, and is adapted from source published in the astroML documentation. Used by permission).

# %%
M = np.ones((2, 3))
a = np.arange(3)

# %% [markdown]
# et's consider an operation on these two arrays. The shape of the arrays are
#
# M.shape = (2, 3)
# a.shape = (3,)
# We see by rule 1 that the array a has fewer dimensions, so we pad it on the left with ones:
#
# M.shape -> (2, 3)
# a.shape -> (1, 3)
# By rule 2, we now see that the first dimension disagrees, so we stretch this dimension to match:
#
# M.shape -> (2, 3)
# a.shape -> (2, 3)
# The shapes match, and we see that the final shape will be (2, 3):

# %%
a = np.arange(3).reshape((3, 1))
b = np.arange(3)

# %%
import numpy as np
np.zeros(10,dtype=int)

# %%
np.array([1, 4, 2, 5, 3])

# %%
np.array([1, 2, 3, 4], dtype='float32')

# %%
np.array([range(i, i + 3) for i in [2, 4, 6]])

# %% [markdown]
# The inner lists are treated as rows of the resulting two-dimensional array.

# %% [markdown]
# ##Creating Arrays from Scratch

# %%
np.zeros(10, dtype=int)

# %%
np.ones((3, 5), dtype=float)

# %%
np.full((3, 5), 3.14)

# %% [markdown]
# ##NumPy Standard Data Types

# %% [markdown]
# NumPy arrays contain values of a single type, so it is important to have detailed knowledge of those types and their limitations. Because NumPy is built in C, the types will be familiar to users of C, Fortran, and other related languages.
#
# The standard NumPy data types are listed in the following table. Note that when constructing an array, they can be specified using a string:

# %%
np.zeros(10, dtype='int16')

# %%
np.zeros(10, dtype=np.int16)

# %% [markdown]
# ##NumPy Array Attributes

# %% [markdown]
# First let's discuss some useful array attributes. We'll start by defining three random arrays, a one-dimensional, two-dimensional, and three-dimensional array. We'll use NumPy's random number generator, which we will seed with a set value in order to ensure that the same random arrays are generated each time this code is run:

# %%
import numpy as np
np.random.seed(0)  # seed for reproducibility

x1 = np.random.randint(10, size=6)  # One-dimensional array
x2 = np.random.randint(10, size=(3, 4))  # Two-dimensional array
x3 = np.random.randint(10, size=(3, 4, 5))  # Three-dimensional array

print("x3 ndim: ", x3.ndim)
print("x3 shape:", x3.shape)
print("x3 size: ", x3.size)

# %% [markdown]
# Another useful attribute is the dtype, the data type of the array (which we discussed previously in Understanding Data Types in Python):

# %%
print("dtype:", x3.dtype)

# %%
print("itemsize:", x3.itemsize, "bytes")
print("nbytes:", x3.nbytes, "bytes")

# %% [markdown]
# ##Array Indexing: Accessing Single Elements

# %%
print(x1)

print(x1[0])

print(x1[-1])

print(x1[-2])

# %% [markdown]
# #### Analisis estadistico con Numpy

# %% [markdown]
# Este documento presenta una guía introductoria al uso de NumPy para realizar análisis estadístico fundamental. NumPy es una biblioteca esencial de Python para el cálculo numérico, ampliamente utilizada en ciencia de datos, machine learning y análisis científico.

# %% [markdown]
# #####📘 Introducción
# NumPy proporciona una estructura de datos eficiente basada en arreglos (ndarray) y un amplio conjunto de funciones matemáticas y estadísticas que permiten:
#
# *   Resumir datos rápidamente
# *   Calcular medidas de tendencia central
# *   Analizar la dispersión
# *   Trabajar con arreglos multidimensionales

# %% [markdown]
# #####Importación de NumPy

# %%
#Media (Mean)
import numpy as np
data = np.array([1, 2, 3, 4, 5])
media = np.mean(data)
print(media)

# %%
#Promedio (Average) y Promedio Ponderado
data = np.array([1, 2, 3, 4, 5])
weights = np.array([1, 2, 3, 4, 5])
promedio = np.average(data)
promedio_ponderado = np.average(data, weights=weights)

# %%
#la media
mediana = np.median(data)

# %%
#Varianza y Desviación Estándar
varianza = np.var(data)
desviacion = np.std(data)

# %%
#Promedio (Average) y Promedio Ponderado
data = np.array([1, 2, 3, 4, 5])
weights = np.array([1, 2, 3, 4, 5])
promedio = np.average(data)
promedio_ponderado = np.average(data, weights=weights)

# %%
#Generación de Datos Aleatorios
muestra = np.random.normal(0, 1, 1000)
print(np.mean(muestra), np.std(muestra))

# %%
#Correlación
corr = np.corrcoef([1,2,3], [1,5,7])

# %%
import numpy as np
import pandas as pd
from io import StringIO

raw = """Marca temporal\tNúmero de matrícula\t¿Cuántos años cumplidos tienes?\t¿Has realizado programas utilizando Python?\t¿Has utilizado Google Colab?\t¿Tienes cuenta de GitHub?
19/01/2026 18:32:18\t178920\t22\tSi\tNo\tSi
19/01/2026 18:32:23\t182712\t21\tSi\tNo\tSi
19/01/2026 18:32:25\t180370\t26\tSi\tSi\tSi
19/01/2026 18:32:27\t182570\t21\tSi\tSi\tSi
19/01/2026 18:32:28\t177622\t24\tSi\tNo\tSi
19/01/2026 18:32:29\t175166\t22\tSi\tSi\tSi
19/01/2026 18:32:30\t177573\t22\tSi\tSi\tSi
19/01/2026 18:32:35\t178430\t21\tSi\tSi\tSi
19/01/2026 18:32:38\t179169\t23\tSi\tNo\tSi
19/01/2026 18:32:41\t177263\t22\tSi\tSi\tSi
19/01/2026 18:32:48\t179884\t23\tSi\tNo\tSi
19/01/2026 18:32:48\t183016\t22\tSi\tNo\tSi
19/01/2026 18:32:50\t179033\t23\tSi\tSi\tNo
19/01/2026 18:32:54\t178218\t22\tSi\tNo\tSi
19/01/2026 18:32:55\t178446\t22\tSi\tSi\tSi
19/01/2026 18:33:00\t178166\t22\tSi\tSi\tNo
19/01/2026 18:33:02\t177406\t22\tSi\tNo\tSi
19/01/2026 18:33:05\t177192\t22\tSi\tSi\tSi
19/01/2026 18:33:08\t182451\t21\tSi\tNo\tSi
19/01/2026 18:33:08\t171513\t24\tNo\tNo\tSi
19/01/2026 18:33:09\t181619\t21\tSi\tNo\tSi
19/01/2026 18:33:12\t182298\t23\tSi\tNo\tSi
19/01/2026 18:33:14\t181419\t24\tNo\tNo\tSi
19/01/2026 18:33:32\t177291\t21\tSi\tSi\tSi
19/01/2026 18:33:42\t182085\t22\tSi\tNo\tSi
19/01/2026 18:33:53\t176453\t22\tSi\tNo\tSi
19/01/2026 18:34:04\t176263\t24\tSi\tNo\tSi
19/01/2026 18:34:06\t179997\t21\tSi\tNo\tSi
19/01/2026 18:36:21\t175842\t23\tSi\tNo\tNo
19/01/2026 20:19:21\t179913\t20\tSi\tNo\tSi
19/01/2026 20:19:48\t177301\t22\tSi\tSi\tNo
19/01/2026 20:20:06\t183060\t21\tSi\tNo\tSi
19/01/2026 20:20:08\t177935\t22\tSi\tSi\tSi
19/01/2026 20:20:19\t177700\t20\tSi\tSi\tSi
19/01/2026 20:20:26\t178318\t24\tSi\tSi\tSi
19/01/2026 20:20:27\t174653\t24\tSi\tNo\tSi
19/01/2026 20:20:29\t177139\t21\tSi\tNo\tSi
19/01/2026 20:20:31\t173479\t25\tSi\tNo\tNo
19/01/2026 20:20:39\t175588\t23\tNo\tNo\tSi
19/01/2026 20:20:45\t178774\t23\tSi\tSi\tSi
19/01/2026 20:20:45\t175031\t23\tSi\tNo\tNo
19/01/2026 20:20:49\t178396\t21\tSi\tSi\tSi
19/01/2026 20:20:49\t172068\t23\tNo\tNo\tNo
19/01/2026 20:20:50\t174197\t23\tNo\tNo\tSi
19/01/2026 20:20:55\t178584\t22\tSi\tNo\tSi
19/01/2026 20:20:55\t175329\t24\tSi\tNo\tSi
19/01/2026 20:20:56\t177685\t22\tSi\tSi\tSi
19/01/2026 20:20:57\t178678\t22\tNo\tNo\tSi
19/01/2026 20:21:04\t177143\t22\tSi\tNo\tSi
19/01/2026 20:21:07\t182318\t26\tSi\tNo\tSi
19/01/2026 20:21:27\t182377\t20\tSi\tNo\tSi
19/01/2026 20:21:34\t179419\t22\tSi\tNo\tNo
19/01/2026 20:21:35\t181662\t21\tSi\tNo\tSi
19/01/2026 20:21:38\t181760\t21\tSi\tNo\tSi
19/01/2026 20:22:06\t177888\t22\tSi\tNo\tSi
19/01/2026 20:22:15\t176535\t25\tSi\tNo\tSi
19/01/2026 20:22:29\t179862\t21\tSi\tNo\tSi
19/01/2026 20:22:32\t178378\t22\tSi\tNo\tSi
19/01/2026 20:22:50\t177451\t22\tSi\tNo\tSi
19/01/2026 20:23:15\t179804\t21\tSi\tNo\tSi
"""
df = pd.read_csv(StringIO(raw), sep='\t')
#/content/drive/MyDrive/mi_drive.txt
df.columns = [c.strip() for c in df.columns]
df.head()

# %%
# Variables
df['edad'] = pd.to_numeric(df['¿Cuántos años cumplidos tienes?'], errors='coerce')
map_sn = {'Si': True, 'No': False}
df['prog_python'] = df['¿Has realizado programas utilizando Python?'].map(map_sn)
df['usa_colab'] = df['¿Has utilizado Google Colab?'].map(map_sn)
df['cuenta_github'] = df['¿Tienes cuenta de GitHub?'].map(map_sn)

# A NumPy
edad = df['edad'].to_numpy(dtype=float)
prog_py = df['prog_python'].to_numpy(dtype=bool)
usa_colab = df['usa_colab'].to_numpy(dtype=bool)
cuenta_gh = df['cuenta_github'].to_numpy(dtype=bool)

print(f'{edad[:5]}')

# %%
# Descriptivos de edad (NumPy)
summary_age = {
    'n': int(edad.size),
    'min': float(np.min(edad)),
    'p25': float(np.percentile(edad, 25)),
    'mediana': float(np.median(edad)),
    'media': float(np.mean(edad)),
    'p75': float(np.percentile(edad, 75)),
    'max': float(np.max(edad)),
    'rango(ptp)': float(np.ptp(edad)),
    'var_muestral': float(np.var(edad, ddof=1)),
    'std_muestral': float(np.std(edad, ddof=1)),
    'cv': float(np.std(edad, ddof=1)/np.mean(edad)),
}
print(summary_age)

# %%
# Frecuencias (NumPy)
freq_python = {'Si': int(np.count_nonzero(prog_py)), 'No': int(edad.size - np.count_nonzero(prog_py))}
freq_colab  = {'Si': int(np.count_nonzero(usa_colab)), 'No': int(edad.size - np.count_nonzero(usa_colab))}
freq_gh     = {'Si': int(np.count_nonzero(cuenta_gh)), 'No': int(edad.size - np.count_nonzero(cuenta_gh))}

# %%
# Tablas cruzadas (NumPy)
def tabla2x2(a, b):
    t = np.zeros((2,2), dtype=int)
    t[1,1] = np.count_nonzero(a & b)
    t[1,0] = np.count_nonzero(a & ~b)
    t[0,1] = np.count_nonzero(~a & b)
    t[0,0] = np.count_nonzero(~a & ~b)
    return t

tab_py_colab = tabla2x2(prog_py, usa_colab)
tab_py_gh    = tabla2x2(prog_py, cuenta_gh)
tab_colab_gh = tabla2x2(usa_colab, cuenta_gh)
print(tab_py_colab)
print(tab_py_gh)
print(tab_colab_gh)

# %%
# Medias de edad por grupo (NumPy)
means_by_group = {
    'edad_promedio_Python': {'Si': float(np.mean(edad[prog_py])) if np.any(prog_py) else np.nan,
                             'No': float(np.mean(edad[~prog_py])) if np.any(~prog_py) else np.nan},
    'edad_promedio_Colab':  {'Si': float(np.mean(edad[usa_colab])) if np.any(usa_colab) else np.nan,
                             'No': float(np.mean(edad[~usa_colab])) if np.any(~usa_colab) else np.nan},
    'edad_promedio_GitHub': {'Si': float(np.mean(edad[cuenta_gh])) if np.any(cuenta_gh) else np.nan,
                             'No': float(np.mean(edad[~cuenta_gh])) if np.any(~cuenta_gh) else np.nan},
}

# %% [markdown]
# ###MSE

# %%
import numpy as np
import pandas as pd

# %%
anios_escolaridad = np.array([0, 3, 6, 9, 12, 16, 18])
ingreso_mensual_estimado_mx = np.array([12621, 15723, 19587, 24401, 30398, 40747, 47176])

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(10, 6))
plt.scatter(anios_escolaridad, ingreso_mensual_estimado_mx)
plt.title('Años de Escolaridad vs. Ingreso Mensual Estimado')
plt.xlabel('Años de Escolaridad')
plt.ylabel('Ingreso Mensual Estimado (MXN)')
plt.grid(True)
plt.show()

# %%
x1 = anios_escolaridad[0]
y1 = ingreso_mensual_estimado_mx[0]
x2 = anios_escolaridad[-1]
y2 = ingreso_mensual_estimado_mx[-1]

m = (y2 - y1) / (x2 - x1)
b = y1 - m * x1

print(f"La ecuación de la recta es: y = {m:.2f}x + {b:.2f}")

# %% [markdown]
# Primer intento de modelar los años de escolaridad y el ingreso estimado.
# Utilizar el primer punto y el útlimo para trazar una recta:
#
# $$m = \frac{y_2 - y_1}{x_2 - x_1}$$

# %% [markdown]
# $$b = y_1 - m \cdot x_1$$

# %%
x1 = anios_escolaridad[0]
y1 = ingreso_mensual_estimado_mx[0]
x2 = anios_escolaridad[-1]
y2 = ingreso_mensual_estimado_mx[-1]

m = (y2 - y1) / (x2 - x1)
b = y1 - m * x1

print(f"La ecuación de la recta es: y = {m:.2f}x + {b:.2f}")

# %%
import matplotlib.pyplot as plt

# Calcular los valores y de la recta utilizando m y b
linea_ingreso_estimado_new_plot = m * anios_escolaridad + b

plt.figure(figsize=(10, 6))
plt.scatter(anios_escolaridad, ingreso_mensual_estimado_mx, label='Datos Originales')
plt.plot(anios_escolaridad, linea_ingreso_estimado_new_plot, color='red',
         label=f'Recta de Regresión (y = {m:.2f}x + {b:.2f})')
plt.title('Años de Escolaridad vs. Ingreso Mensual Estimado con Línea de Regresión')
plt.xlabel('Años de Escolaridad')
plt.ylabel('Ingreso Mensual Estimado (MXN)')
plt.grid(True)
plt.legend()
plt.show()

# %% [markdown]
# Valores predichos
# : Son los ingresos mensuales que nuestra recta de regresión predice para cada año de escolaridad.
#
# Errores (residuales): Es la diferencia entre el ingreso mensual real (ingreso_mensual_estimado_mx) y el ingreso mensual predicho (y_pred). Un error positivo significa que la predicción fue menor que el valor real, y un error negativo indica que la predicción fue mayor.
#
# Errores al cuadrado: Hemos elevado al cuadrado cada uno de los errores. Esto se hace para eliminar los signos negativos (de modo que los errores positivos y negativos no se cancelen entre sí) y para penalizar más los errores grandes.
#
# Suma de errores cuadrados: Es la suma de todos los errores al cuadrado. Este valor nos da una medida total de la 'distancia' de nuestros puntos a la línea.
#
# Error Cuadrático Medio (MSE): Es la suma de los errores cuadrados dividida por el número total de puntos de datos. El MSE es una medida promedio de la magnitud de los errores. Un MSE más bajo indica que el modelo se ajusta mejor a los datos.
#
# En este caso, el Error Cuadrático Medio (MSE) es de aproximadamente 13,196,667.31. Este número nos da una idea del rendimiento general de la recta que trazamos, mostrando la magnitud promedio de los errores al cuadrado entre los valores observados y los valores predichos por la línea.
#
# Fórmula del MSE (Error Cuadrático Medio) del Inglés Mean Squared Error
#
# $$MSE = \frac{1}{n} \sum_{i=1}^{n} (y_i - \hat{y}_i)^2$$

# %%
# 1. Calcular los valores predichos (y_pred) usando la ecuación de la recta
y_pred = m * anios_escolaridad + b
y_pred

# %%
# 2. Calcular los errores (residuales): la diferencia entre los valores reales y los predichos
errores = ingreso_mensual_estimado_mx - y_pred
errores

# %%
# 3. Elevar al cuadrado cada error
errores_cuadrados = errores**2
errores_cuadrados

# %%
# 4. Sumar los errores cuadrados
suma_errores_cuadrados = np.sum(errores_cuadrados)
suma_errores_cuadrados

# %%
# 5. Dividir la suma de los errores cuadrados por el número de puntos para obtener el MSE
mse = suma_errores_cuadrados / len(anios_escolaridad)
print(mse)

# %% [markdown]
# np.float64(13196667.305996465)
#
# Ahora comparemos el MSE de una regresión lineal.
# Por ahora no es importante el detalle de la regrsión lineal.
# Lo importante es comparar el MSE.

# %%
from sklearn.linear_model import LinearRegression
import numpy as np

# %%
# Cambia la forma de anios_escolaridad a 2D array como es requerido por sklearn
X = anios_escolaridad.reshape(-1, 1)
y = ingreso_mensual_estimado_mx

print(X)
print(y)

# %%
# Crear y ajustar el modelo de regresión lineal
modelo_regresion = LinearRegression()
modelo_regresion.fit(X, y)

# Obtener los coeficientes (m) e intercepto (b) del nuevo modelo
m_sklearn = modelo_regresion.coef_[0]
b_sklearn = modelo_regresion.intercept_

print(f"Coefficients (m) from scikit-learn: {m_sklearn:.2f}")
print(f"Intercept (b) from scikit-learn: {b_sklearn:.2f}")

# %% [markdown]
# http://www.occ.com.mx/empleo/oferta/20915935

# %% [markdown]
# ```
# # Esto tiene formato de código
# ```
#
# #PARCIAL 2

# %% [markdown]
# ##EJERCICIO 1

# %% [markdown]
# Which bird has the fewest neck vertebra?
# Find the row with the minimum number of neck vertebrae.

# %%
df = pd.read_csv('/content/bird-neck-bones.csv')
df

# %%
df=df.query('neck_vertebrae == neck_vertebrae.min()')
df

# %% [markdown]
# Do humans have more bones in the arms or legs?
# Filter the rows where the region is arm. Repeat with leg.

# %%
df = pd.read_csv('/content/adult-human-skeleton.csv')
df

# %%
arm = df.query('region == "arm"')
leng = df.query('region == "leg"')

print(arm.shape[0])
print(leng.shape[0])

# %% [markdown]
# How many ribs to humans have?
# Filter the rows where the name contains the word rib. Hint: name.str.contains("rib"). To count the number of rows, use the dataframe function df.shape. This will return the number of rows and columns in the dataframe.

# %%
#Filter the rows where the name contains the word rib.
df = pd.read_csv('/content/adult-human-skeleton.csv')
df

# %%
df_ribs = df[df['name'].str.contains("rib", case=False)]
num_rows = df_ribs.shape[0]
print(f"Number of rows containing 'rib': {num_rows}")

# %% [markdown]
# ##EJERCICIO 2

# %% [markdown]
# 1. Determine the year when more than 50% of the population in a continent of your choice first gained internet access.

# %%
import pandas as pd
import matplotlib.pyplot as plt

# 1. Asegúrate de tener cargados ambos archivos
internet_users_by_continent = pd.read_csv('/content/extension-internet-users-by-continent.csv')

df_internet = pd.read_csv('/content/extension-internet-users-by-continent.csv')
df_poblacion = pd.read_csv('/content/extension-historical-population-by-continent.csv')

# 2. Unir los datasets por 'continent' y 'year'
df_combined = pd.merge(internet_users_by_continent, df_poblacion, on=['continent', 'year'])

# 3. Calcular la penetración (Escala de Razón)
df_combined['penetration_pct'] = (df_combined['internet_users'] / df_combined['population']) * 100

# 4. Elegir un continente
continente_objetivo = 'Europe'

# 5. Filtrar registros donde la penetración es > 50%
filtro_50 = df_combined[(df_combined['continent'] == continente_objetivo) & (df_combined['penetration_pct'] > 50)]

# 6. Obtener el primer año (el valor mínimo de la columna 'year')
primer_año_50 = filtro_50['year'].min()

print(f"En el continente {continente_objetivo}, más del 50% de la población")
print(f"tuvo acceso a internet por primera vez en el año: {primer_año_50}")

# %% [markdown]
# 2. Explore and analyze internet usage and population data for a specific region or country of interest, such as by sourcing information from sites like ourworldindata.org.

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# 1. Carga de datos
internet = pd.read_csv('extension-internet-users-by-continent.csv')
population = pd.read_csv('/content/extension-historical-population-by-continent.csv')

# 2. Unión de datos
# Unimos por continente y año para tener una sola tabla de análisis
df_analisis = pd.merge(internet_users_by_continent, df_poblacion, on=['continent', 'year'])

# 3. Creación de métrica de penetración (Escala de Razón)
# Calculamos el porcentaje: (Usuarios / Población) * 100
df_analisis['internet_penetration'] = (df_analisis['internet_users'] / df_analisis['population']) * 100

# 4. Filtrar por una región de interés
region_interes = 'Asia'
df_region = df_analisis[df_analisis['continent'] == region_interes].sort_values('year')

print(f"Análisis para la región: {region_interes}")
df_region.tail()

# %%
fig, ax1 = plt.subplots(figsize=(12, 6))

# Graficar Población (Eje izquierdo)
sns.lineplot(data=df_region, x='year', y='population', ax=ax1, color='blue', label='Población Total')
ax1.set_ylabel('Población', color='blue')

# Crear un segundo eje para Usuarios de Internet (Eje derecho)
ax2 = ax1.twinx()
sns.lineplot(data=df_region, x='year', y='internet_users', ax=ax2, color='green', label='Usuarios Internet')
ax2.set_ylabel('Usuarios de Internet', color='green')

plt.title(f'Crecimiento de Población vs Adopción de Internet en {region_interes}')
plt.grid(True, alpha=0.3)
plt.show()

# %% [markdown]
# #PARCIAL 3

# %%
import math

# Datos de entrenamiento
X = [(2,4), (4,4), (4,2), (6,2)]
y = ['Rojo', 'Rojo', 'Azul', 'Azul']

# Punto a clasificar
P = (3, 3)

# %%
def distancia_euclidiana(p1, p2):
    return math.sqrt((p1[0]-p2[0])**2 + (p1[1]-p2[1])**2)

# %%
distancias = []
for i in range(len(X)):
    d = distancia_euclidiana(P, X[i])
    distancias.append((d, y[i]))

# Ordenar por distancia
distancias.sort(key=lambda x: x[0])

print(distancias)
print("Clase asignada:", distancias[0][1])

# %%
from collections import Counter

k = 3
vecinos = distancias[:k]

clases = [clase for _, clase in vecinos]
resultado = Counter(clases).most_common(1)

print("Vecinos:", vecinos)
print("Clase asignada:", resultado[0][0])

# %%
def distancia_manhattan(p1, p2):
    return abs(p1[0]-p2[0]) + abs(p1[1]-p2[1])

X = [(1,1), (2,3), (5,4), (6,5)]
y = ['Baja', 'Baja', 'Alta', 'Alta']
P = (4,3)

distancias = []

for i in range(len(X)):
    d = distancia_manhattan(P, X[i])
    distancias.append((d, y[i]))

distancias.sort(key=lambda x: x[0])

print(distancias)
print("Clase asignada:", distancias[0][1])

# %%
import numpy as np
from sklearn.neighbors import KNeighborsClassifier

# %%
X = np.array([
[5.1, 3.5],
[4.9, 3.0],
[6.2, 3.4],
[6.0, 2.9]
])

y = np.array(['Setosa', 'Setosa', 'Versicolor', 'Versicolor'])

P = np.array([[5.8, 3.2]])

# %%
modelo = KNeighborsClassifier(n_neighbors=3)
modelo.fit(X, y)

prediccion = modelo.predict(P)
print("Clase predicha:", prediccion[0])

# %% [markdown]
# ###Parte A: k‑NN SIN normalización

# %%
import numpy as np
from sklearn.neighbors import KNeighborsClassifier

# Dataset
X = np.array([
[25, 8000],
[30, 12000],
[45, 45000],
[50, 60000],
[35, 15000],
[48, 55000]
])

y = np.array(['Alto', 'Alto', 'Bajo', 'Bajo', 'Alto', 'Bajo'])

nuevo_cliente = np.array([[40, 20000]])

# Modelo k-NN
modelo = KNeighborsClassifier(n_neighbors=3)
modelo.fit(X, y)

# Predicción
modelo.predict(nuevo_cliente)

# %% [markdown]
# ###Parte B: k‑NN CON normalización

# %%
from sklearn.preprocessing import StandardScaler

# Escalamiento
scaler = StandardScaler()
X_norm = scaler.fit_transform(X)
nuevo_norm = scaler.transform(nuevo_cliente)

# Modelo k-NN
modelo_norm = KNeighborsClassifier(n_neighbors=3)
modelo_norm.fit(X_norm, y)

# Predicción
modelo_norm.predict(nuevo_norm)

# %% [markdown]
# ###EJERCICIO K-NN

# %%
"""
Utiliza el dataset de las flores Iris.

Realiza una seprción de conjunto de datos de entrenmineo ty de prueba de la siguiente manera:

Entrenamineot 80%
Prueba 20%
Evalua la clasificación utilizando K-NN

Investiga que es el codo

Y determina el valor de k adecuaduado para clasificar las flores Iris
"""

#aqui cargamos todo lo que tiene que ver con iris
import seaborn as sns
iris=sns.load_dataset('iris')
iris.head()

# %%
from sklearn.model_selection import train_test_split
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import accuracy_score
import matplotlib.pyplot as plt

# Separar características y etiquetas
X = iris.drop('species', axis=1)
y = iris['species']

# División 80% entrenamiento, 20% prueba
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.20, random_state=42)

# %%
error_rate = []

# Probar valores de k del 1 al 40
for i in range(1, 40):
    knn = KNeighborsClassifier(n_neighbors=i)
    knn.fit(X_train, y_train)
    pred_i = knn.predict(X_test)
    error_rate.append(1 - accuracy_score(y_test, pred_i))

# Graficar el método del codo
plt.figure(figsize=(10,6))
plt.plot(range(1,40), error_rate, color='blue', linestyle='dashed', marker='o', markerfacecolor='red')
plt.title('Tasa de Error vs. Valor de K')
plt.xlabel('K')
plt.ylabel('Tasa de Error')
plt.show()

# %% [markdown]
# ###In-Depth: Decision Trees and Random Forests

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns; sns.set()

# %%
from sklearn.datasets import make_blobs

X, y = make_blobs(n_samples=300, centers=4,
                  random_state=0, cluster_std=1.0)
plt.scatter(X[:, 0], X[:, 1], c=y, s=50, cmap='rainbow');

# %%
from sklearn.tree import DecisionTreeClassifier
tree = DecisionTreeClassifier().fit(X, y)

# %%
def visualize_classifier(model, X, y, ax=None, cmap='rainbow'):
    ax = ax or plt.gca()

    # Plot the training points
    ax.scatter(X[:, 0], X[:, 1], c=y, s=30, cmap=cmap,
               clim=(y.min(), y.max()), zorder=3)
    ax.axis('tight')
    ax.axis('off')
    xlim = ax.get_xlim()
    ylim = ax.get_ylim()

    # fit the estimator
    model.fit(X, y)
    xx, yy = np.meshgrid(np.linspace(*xlim, num=200),
                         np.linspace(*ylim, num=200))
    Z = model.predict(np.c_[xx.ravel(), yy.ravel()]).reshape(xx.shape)

    # Create a color plot with the results
    n_classes = len(np.unique(y))
    contours = ax.contourf(xx, yy, Z, alpha=0.3,
                           levels=np.arange(n_classes + 1) - 0.5,
                           cmap=cmap, clim=(y.min(), y.max()),
                           zorder=1)

    ax.set(xlim=xlim, ylim=ylim)

# %%
visualize_classifier(DecisionTreeClassifier(), X, y)

# %%
rng = np.random.RandomState(42)
x = 10 * rng.rand(200)

def model(x, sigma=0.3):
    fast_oscillation = np.sin(5 * x)
    slow_oscillation = np.sin(0.5 * x)
    noise = sigma * rng.randn(len(x))

    return slow_oscillation + fast_oscillation + noise

y = model(x)
plt.errorbar(x, y, 0.3, fmt='o');

# %%
from sklearn.ensemble import RandomForestRegressor
forest = RandomForestRegressor(200)
forest.fit(x[:, None], y)

xfit = np.linspace(0, 10, 1000)
yfit = forest.predict(xfit[:, None])
ytrue = model(xfit, sigma=0)

plt.errorbar(x, y, 0.3, fmt='o', alpha=0.5)
plt.plot(xfit, yfit, '-r');
plt.plot(xfit, ytrue, '-k', alpha=0.5);

# %%
from sklearn.datasets import load_digits
digits = load_digits()
digits.keys()

# %%
# set up the figure
fig = plt.figure(figsize=(6, 6))  # figure size in inches
fig.subplots_adjust(left=0, right=1, bottom=0, top=1, hspace=0.05, wspace=0.05)

# plot the digits: each image is 8x8 pixels
for i in range(64):
    ax = fig.add_subplot(8, 8, i + 1, xticks=[], yticks=[])
    ax.imshow(digits.images[i], cmap=plt.cm.binary, interpolation='nearest')

    # label the image with the target value
    ax.text(0, 7, str(digits.target[i]))

# %%
from sklearn.datasets import load_digits
from sklearn.model_selection import train_test_split
# ERROR CORREGIDO: Importar el clasificador
from sklearn.ensemble import RandomForestClassifier

# 1. Cargar el dataset de dígitos
digits = load_digits()

# 2. División de datos
Xtrain, Xtest, ytrain, ytest = train_test_split(digits.data, digits.target,
                                                random_state=0)

# 3. Definir el modelo
model = RandomForestClassifier(n_estimators=1000)

# 4. Entrenar
model.fit(Xtrain, ytrain)

# 5. Predecir
ypred = model.predict(Xtest)

# Opcional: Ver el desempeño
from sklearn import metrics
print(metrics.classification_report(ypred, ytest))

# %%
from sklearn import metrics
print(metrics.classification_report(ypred, ytest))

# %%
from sklearn.metrics import confusion_matrix
mat = confusion_matrix(ytest, ypred)
sns.heatmap(mat.T, square=True, annot=True, fmt='d', cbar=False)
plt.xlabel('true label')
plt.ylabel('predicted label');

# %% [markdown]
# ###Liga MX jornada 16 - Predicción utilizando Random Forest Minería de DatosLiga MX jornada 16 - Predicción utilizando Random Forest

# %%
import pandas as pd
import numpy as np

## Cargar dataset
df = pd.read_csv('/content/dataset_liga_mx_jornadas_13_14_15_base.csv')
df.head()

## Selección de features
features = ['diff_puntos','diff_racha','diff_posicion']
X = df[features]
y = df['resultado']

## Entrenamiento del Random Forest
from sklearn.ensemble import RandomForestClassifier
rf = RandomForestClassifier(n_estimators=300, max_depth=5, random_state=42)
rf.fit(X, y)

## Importancia de variables
importances = pd.Series(rf.feature_importances_, index=features)
importances.sort_values(ascending=False)

## Visualización de un árbol
from sklearn.tree import plot_tree
import matplotlib.pyplot as plt
plt.figure(figsize=(20,10))
plot_tree(rf.estimators_[0], feature_names=features, class_names=['Visita','Empate','Local'], filled=True)
plt.show()

# %%
# Definir los datos del partido Querétaro vs Cruz Azul (Jornada 16)
partido_j16 = pd.DataFrame([[ -13, -1, 9 ]], columns=['diff_puntos', 'diff_racha', 'diff_posicion'])

# Realizar la predicción
prediccion_codificada = rf.predict(partido_j16)

# Mapear el resultado
resultados_map = {0: 'Victoria Cruz Azul (Visita)', 1: 'Empate', 2: 'Victoria Querétaro (Local)'}
resultado_final = resultados_map[prediccion_codificada[0]]

print(f"Predicción para Querétaro vs Cruz Azul: {resultado_final}")

# Ver las probabilidades
probabilidades = rf.predict_proba(partido_j16)
print(f"Probabilidades [Visita, Empate, Local]: {probabilidades}")

# %%
# 1. Definir los datos de entrada para Pumas vs Juárez
partido_pumas_juarez = pd.DataFrame([[14, 6, -9]],
                                    columns=['diff_puntos', 'diff_racha', 'diff_posicion'])

# 2. Realizar la predicción con el modelo ya entrenado
pred_codificada = rf.predict(partido_pumas_juarez)
probabilidades = rf.predict_proba(partido_pumas_juarez)

# 3. Mapeo de resultados
# 2: Local, 1: Empate, 0: Visita
res_map = {2: 'Victoria Pumas UNAM (Local)', 1: 'Empate', 0: 'Victoria FC Juárez (Visita)'}

print(f"--- Predicción Jornada 16 ---")
print(f"Partido: Pumas UNAM vs FC Juárez")
print(f"Resultado estimado: {res_map[pred_codificada[0]]}")
print(f"Probabilidades [Visita, Empate, Local]: {probabilidades[0]}")

# %%
# 1. Definir los datos de entrada para Monterrey vs Puebla
partido_mty_puebla = pd.DataFrame([[2, 1, -2]],
                                   columns=['diff_puntos', 'diff_racha', 'diff_posicion'])

# 2. Realizar la predicción
pred_codificada = rf.predict(partido_mty_puebla)
probabilidades = rf.predict_proba(partido_mty_puebla)

# 3. Mapeo de resultados
res_map = {2: 'Victoria Monterrey (Local)', 1: 'Empate', 0: 'Victoria Puebla (Visita)'}

print(f"--- Predicción Jornada 16 ---")
print(f"Partido: Monterrey vs Puebla")
print(f"Resultado estimado: {res_map[pred_codificada[0]]}")
print(f"Probabilidades [Visita, Empate, Local]: {probabilidades[0]}")

# %%
# 1. Definir los datos de entrada para León vs América
partido_leon_america = pd.DataFrame([[0, 3, 2]],
                                     columns=['diff_puntos', 'diff_racha', 'diff_posicion'])

# 2. Realizar la predicción
pred_codificada = rf.predict(partido_leon_america)
probabilidades = rf.predict_proba(partido_leon_america)

# 3. Mapeo de resultados
res_map = {2: 'Victoria León (Local)', 1: 'Empate', 0: 'Victoria América (Visita)'}

print(f"--- Predicción Jornada 16 ---")
print(f"Partido: León vs América")
print(f"Resultado estimado: {res_map[pred_codificada[0]]}")
print(f"Probabilidades [Visita, Empate, Local]: {probabilidades[0]}")

# %%
# 1. Definir los datos de entrada para Atlas vs Tigres
# diff_puntos=-12, diff_racha=-4, diff_posicion=9
partido_atlas_tigres = pd.DataFrame([[-12, -4, 9]],
                                     columns=['diff_puntos', 'diff_racha', 'diff_posicion'])

# 2. Realizar la predicción
pred_codificada = rf.predict(partido_atlas_tigres)
probabilidades = rf.predict_proba(partido_atlas_tigres)

# 3. Mapeo de resultados
res_map = {2: 'Victoria Atlas (Local)', 1: 'Empate', 0: 'Victoria Tigres UANL (Visita)'}

print(f"--- Predicción Jornada 16 ---")
print(f"Partido: Atlas vs Tigres UANL")
print(f"Resultado estimado: {res_map[pred_codificada[0]]}")
print(f"Probabilidades [Visita, Empate, Local]: {probabilidades[0]}")

# %%
# 1. Definir los datos de entrada para San Luis vs Santos
partido_asl_santos = pd.DataFrame([[-7, -1, 8]],
                                   columns=['diff_puntos', 'diff_racha', 'diff_posicion'])

# 2. Realizar la predicción
pred_codificada = rf.predict(partido_asl_santos)
probabilidades = rf.predict_proba(partido_asl_santos)

# 3. Mapeo de resultados
res_map = {2: 'Victoria Atlético San Luis (Local)', 1: 'Empate', 0: 'Victoria Santos Laguna (Visita)'}

print(f"--- Predicción Jornada 16 ---")
print(f"Partido: Atlético San Luis vs Santos Laguna")
print(f"Resultado estimado: {res_map[pred_codificada[0]]}")
print(f"Probabilidades [Visita, Empate, Local]: {probabilidades[0]}")

# %%
# 1. Definir los datos de entrada para Mazatlán vs Toluca
partido_mzt_tol = pd.DataFrame([[-12, 0, 12]],
                                columns=['diff_puntos', 'diff_racha', 'diff_posicion'])

# 2. Realizar la predicción
pred_codificada = rf.predict(partido_mzt_tol)
probabilidades = rf.predict_proba(partido_mzt_tol)

# 3. Mapeo de resultados
res_map = {2: 'Victoria Mazatlán FC (Local)', 1: 'Empate', 0: 'Victoria Toluca (Visita)'}

print(f"--- Predicción Jornada 16 ---")
print(f"Partido: Mazatlán FC vs Toluca")
print(f"Resultado estimado: {res_map[pred_codificada[0]]}")
print(f"Probabilidades [Visita, Empate, Local]: {probabilidades[0]}")

# %%
# 1. Definir los datos de entrada para Necaxa vs Chivas
partido_nec_chi = pd.DataFrame([[-17, -4, 10]],
                                columns=['diff_puntos', 'diff_racha', 'diff_posicion'])

# 2. Realizar la predicción
pred_codificada = rf.predict(partido_nec_chi)
probabilidades = rf.predict_proba(partido_nec_chi)

# 3. Mapeo de resultados
res_map = {2: 'Victoria Necaxa (Local)', 1: 'Empate', 0: 'Victoria Chivas (Visita)'}

print(f"--- Predicción Jornada 16 ---")
print(f"Partido: Necaxa vs Chivas")
print(f"Resultado estimado: {res_map[pred_codificada[0]]}")
print(f"Probabilidades [Visita, Empate, Local]: {probabilidades[0]}")

# %%
# 1. Definir los datos de entrada para Tijuana vs Pachuca
partido_tij_pac = pd.DataFrame([[-12, -5, 8]],
                                columns=['diff_puntos', 'diff_racha', 'diff_posicion'])

# 2. Realizar la predicción
pred_codificada = rf.predict(partido_tij_pac)
probabilidades = rf.predict_proba(partido_tij_pac)

# 3. Mapeo de resultados
res_map = {2: 'Victoria Tijuana (Local)', 1: 'Empate', 0: 'Victoria Pachuca (Visita)'}

print(f"--- Predicción Jornada 16 ---")
print(f"Partido: Tijuana vs Pachuca")
print(f"Resultado estimado: {res_map[pred_codificada[0]]}")
print(f"Probabilidades [Visita, Empate, Local]: {probabilidades[0]}")

# %%
import pandas as pd

data_j16 = {
    'Partido': ['Querétaro vs Cruz Azul', 'Pumas vs FC Juárez', 'Monterrey vs Puebla',
                'León vs América', 'Atlas vs Tigres', 'San Luis vs Santos',
                'Mazatlán vs Toluca', 'Necaxa vs Chivas', 'Tijuana vs Pachuca'],
    'diff_puntos': [-13, 14, 2, 0, -12, -7, -12, -17, -12],
    'diff_racha': [-1, 6, 1, 3, -4, -1, 0, -4, -5],
    'diff_posicion': [9, -9, -2, 2, 9, 8, 12, 10, 8]
}

df_j16 = pd.DataFrame(data_j16)
features = ['diff_puntos', 'diff_racha', 'diff_posicion']

# Predicciones
df_j16['Pred_Codificada'] = rf.predict(df_j16[features])
res_map = {2: 'Local', 1: 'Empate', 0: 'Visita'}
df_j16['Pronóstico'] = df_j16['Pred_Codificada'].map(res_map)

print(df_j16[['Partido', 'Pronóstico']])

# %%
# Crear el DataFrame con los enfrentamientos de la J16
j16_data = {
    'Partido': ['Pumas vs Juárez', 'Mty vs Puebla', 'León vs América', 'Atlas vs Tigres', 'San Luis vs Santos', 'Mzt vs Toluca', 'Nec vs Chivas', 'Tij vs Pachuca'],
    'diff_puntos': [14, 2, 0, -12, -7, -12, -17, -12],
    'diff_racha': [6, 1, 3, -4, -1, 0, -4, -5],
    'diff_posicion': [-9, -2, 2, 9, 8, 12, 10, 8]
}

df_pred = pd.DataFrame(j16_data)

# Predecir con el modelo rf entrenado
df_pred['Cod_Resultado'] = rf.predict(df_pred[['diff_puntos', 'diff_racha', 'diff_posicion']])

# Mapear los nombres de los resultados
# Asumiendo 0: Visita, 1: Empate, 2: Local
mapa = {0: 'Visita', 1: 'Empate', 2: 'Local'}
df_pred['Ganador_Probable'] = df_pred['Cod_Resultado'].map(mapa)

print(df_pred[['Partido', 'Ganador_Probable']])

# %% [markdown]
# ###In-Depth: Support Vector Machines

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy import stats

# use seaborn plotting defaults
import seaborn as sns; sns.set()

# %%
from sklearn.datasets import make_blobs
import matplotlib.pyplot as plt

# Generar los datos
X, y = make_blobs(n_samples=50, centers=2,
                  random_state=0, cluster_std=0.60)

# Graficar
plt.scatter(X[:, 0], X[:, 1], c=y, s=50, cmap='autumn')
plt.show()

# %%
xfit = np.linspace(-1, 3.5)
plt.scatter(X[:, 0], X[:, 1], c=y, s=50, cmap='autumn')
plt.plot([0.6], [2.1], 'x', color='red', markeredgewidth=2, markersize=10)

for m, b in [(1, 0.65), (0.5, 1.6), (-0.2, 2.9)]:
    plt.plot(xfit, m * xfit + b, '-k')

plt.xlim(-1, 3.5);

# %%
xfit = np.linspace(-1, 3.5)
plt.scatter(X[:, 0], X[:, 1], c=y, s=50, cmap='autumn')

for m, b, d in [(1, 0.65, 0.33), (0.5, 1.6, 0.55), (-0.2, 2.9, 0.2)]:
    yfit = m * xfit + b
    plt.plot(xfit, yfit, '-k')
    plt.fill_between(xfit, yfit - d, yfit + d, edgecolor='none',
                     color='#AAAAAA', alpha=0.4)

plt.xlim(-1, 3.5);

# %%
from sklearn.svm import SVC # "Support vector classifier"
model = SVC(kernel='linear', C=1E10)
model.fit(X, y)

# %%
def plot_svc_decision_function(model, ax=None, plot_support=True):
    """Plot the decision function for a 2D SVC"""
    if ax is None:
        ax = plt.gca()
    xlim = ax.get_xlim()
    ylim = ax.get_ylim()

    # create grid to evaluate model
    x = np.linspace(xlim[0], xlim[1], 30)
    y = np.linspace(ylim[0], ylim[1], 30)
    Y, X = np.meshgrid(y, x)
    xy = np.vstack([X.ravel(), Y.ravel()]).T
    P = model.decision_function(xy).reshape(X.shape)

    # plot decision boundary and margins
    ax.contour(X, Y, P, colors='k',
               levels=[-1, 0, 1], alpha=0.5,
               linestyles=['--', '-', '--'])

    # plot support vectors
    if plot_support:
        ax.scatter(model.support_vectors_[:, 0],
                   model.support_vectors_[:, 1],
                   s=300, linewidth=1, facecolors='none');
    ax.set_xlim(xlim)
    ax.set_ylim(ylim)

# %%
plt.scatter(X[:, 0], X[:, 1], c=y, s=50, cmap='autumn')
plot_svc_decision_function(model);

# %%
def plot_svm(N=10, ax=None):
    X, y = make_blobs(n_samples=200, centers=2,
                      random_state=0, cluster_std=0.60)
    X = X[:N]
    y = y[:N]
    model = SVC(kernel='linear', C=1E10)
    model.fit(X, y)

    ax = ax or plt.gca()
    ax.scatter(X[:, 0], X[:, 1], c=y, s=50, cmap='autumn')
    ax.set_xlim(-1, 4)
    ax.set_ylim(-1, 6)
    plot_svc_decision_function(model, ax)

fig, ax = plt.subplots(1, 2, figsize=(16, 6))
fig.subplots_adjust(left=0.0625, right=0.95, wspace=0.1)
for axi, N in zip(ax, [60, 120]):
    plot_svm(N, axi)
    axi.set_title('N = {0}'.format(N))

# %%
from ipywidgets import interact, fixed
interact(plot_svm, N=[10, 200], ax=fixed(None));

# %%
from sklearn.datasets import make_circles
X, y = make_circles(100, factor=.1, noise=.1)

clf = SVC(kernel='linear').fit(X, y)

plt.scatter(X[:, 0], X[:, 1], c=y, s=50, cmap='autumn')
plot_svc_decision_function(clf, plot_support=False);

# %%
r = np.exp(-(X ** 2).sum(1))

# %%
from mpl_toolkits import mplot3d

def plot_3D(elev=30, azim=30, X=X, y=y):
    ax = plt.subplot(projection='3d')
    ax.scatter3D(X[:, 0], X[:, 1], r, c=y, s=50, cmap='autumn')
    ax.view_init(elev=elev, azim=azim)
    ax.set_xlabel('x')
    ax.set_ylabel('y')
    ax.set_zlabel('r')

interact(plot_3D, elev=[-90, 90], azip=(-180, 180),
         X=fixed(X), y=fixed(y));

# %%
clf = SVC(kernel='rbf', C=1E6)
clf.fit(X, y)

# %%
plt.scatter(X[:, 0], X[:, 1], c=y, s=50, cmap='autumn')
plot_svc_decision_function(clf)
plt.scatter(clf.support_vectors_[:, 0], clf.support_vectors_[:, 1],
            s=300, lw=1, facecolors='none');

# %%
X, y = make_blobs(n_samples=100, centers=2,
                  random_state=0, cluster_std=1.2)
plt.scatter(X[:, 0], X[:, 1], c=y, s=50, cmap='autumn');

# %%
X, y = make_blobs(n_samples=100, centers=2,
                  random_state=0, cluster_std=0.8)

fig, ax = plt.subplots(1, 2, figsize=(16, 6))
fig.subplots_adjust(left=0.0625, right=0.95, wspace=0.1)

for axi, C in zip(ax, [10.0, 0.1]):
    model = SVC(kernel='linear', C=C).fit(X, y)
    axi.scatter(X[:, 0], X[:, 1], c=y, s=50, cmap='autumn')
    plot_svc_decision_function(model, axi)
    axi.scatter(model.support_vectors_[:, 0],
                model.support_vectors_[:, 1],
                s=300, lw=1, facecolors='none');
    axi.set_title('C = {0:.1f}'.format(C), size=14)

# %%
from sklearn.datasets import fetch_lfw_people
faces = fetch_lfw_people(min_faces_per_person=60)
print(faces.target_names)
print(faces.images.shape)

# %%
fig, ax = plt.subplots(3, 5)
for i, axi in enumerate(ax.flat):
    axi.imshow(faces.images[i], cmap='bone')
    axi.set(xticks=[], yticks=[],
            xlabel=faces.target_names[faces.target[i]])

# %%
from sklearn.svm import SVC
# 1. Cambiamos RandomizedPCA por PCA
from sklearn.decomposition import PCA
from sklearn.pipeline import make_pipeline

# 2. Configuramos PCA para que use el solver 'randomized'
pca = PCA(n_components=150, svd_solver='randomized', whiten=True, random_state=42)
svc = SVC(kernel='rbf', class_weight='balanced')

# 3. El pipeline se mantiene igual
model = make_pipeline(pca, svc)

# %%
# Cambia esto:
# from sklearn.cross_validation import train_test_split

# Por esto:
from sklearn.model_selection import train_test_split

Xtrain, Xtest, ytrain, ytest = train_test_split(faces.data, faces.target,
                                                random_state=42)

# %%
# Cambia esto:
# from sklearn.grid_search import GridSearchCV

# Por esto:
from sklearn.model_selection import GridSearchCV

param_grid = {'svc__C': [1, 5, 10, 50],
              'svc__gamma': [0.0001, 0.0005, 0.001, 0.005]}
grid = GridSearchCV(model, param_grid)

# %time grid.fit(Xtrain, ytrain)
print(grid.best_params_)

# %%
model = grid.best_estimator_
yfit = model.predict(Xtest)

# %%
fig, ax = plt.subplots(4, 6)
for i, axi in enumerate(ax.flat):
    axi.imshow(Xtest[i].reshape(62, 47), cmap='bone')
    axi.set(xticks=[], yticks=[])
    axi.set_ylabel(faces.target_names[yfit[i]].split()[-1],
                   color='black' if yfit[i] == ytest[i] else 'red')
fig.suptitle('Predicted Names; Incorrect Labels in Red', size=14);

# %%
from sklearn.metrics import classification_report
print(classification_report(ytest, yfit,
                            target_names=faces.target_names))

# %%
from sklearn.metrics import confusion_matrix
mat = confusion_matrix(ytest, yfit)
sns.heatmap(mat.T, square=True, annot=True, fmt='d', cbar=False,
            xticklabels=faces.target_names,
            yticklabels=faces.target_names)
plt.xlabel('true label')
plt.ylabel('predicted label');

# %% [markdown]
# ###Clasificación de Dígitos Manuscritos

# %% [markdown]
# 1. Preparación de los DatosPrimero, necesitamos la "materia prima". El dataset digits ya viene listo, pero hay que darle el formato que los modelos entienden.Importación:

# %%
import matplotlib.pyplot as plt
import numpy as np
from sklearn import datasets
from sklearn.model_selection import train_test_split
from sklearn.neighbors import KNeighborsClassifier
from sklearn.svm import SVC
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix
import seaborn as sns

# 1. Cargar el dataset
digits = datasets.load_digits()

fix, axes = plt.subplots(1, 5, figsize=(10, 3))
for ax, image, label in zip(axes, digits.images, digits.target):
    ax.set_axis_off()
    ax.imshow(image, cmap=plt.cm.gray_r, interpolation='nearest')
    ax.set_title(f'Etiqueta: {label}')
plt.show()

# %%
# convertir 8x8 en un vector de 64 elementos
n_samples = len(digits.images)
data = digits.images.reshape((n_samples, -1))

X_train, X_test, y_train, y_test = train_test_split(
    data, digits.target, test_size=0.2, shuffle=True, random_state=42
)

# %%
# Definir los modelos
modelos = {
    "KNN (k=5)": KNeighborsClassifier(n_neighbors=5),
    "SVM (RBF)": SVC(kernel='rbf', gamma='scale'),
    "Random Forest": RandomForestClassifier(n_estimators=100, random_state=42)
}

# Entrenar y evaluar cada uno
for nombre, modelo in modelos.items():
    modelo.fit(X_train, y_train)
    predicciones = modelo.predict(X_test)
    accuracy = accuracy_score(y_test, predicciones)
    print(f"{nombre} - Exactitud: {accuracy:.4f}")

# %% [markdown]
# 3. El Desafío de la Creación. Esta es la parte creativa. Debes generar tres arreglos de $8 \times 8$.Ojo con los valores: En el dataset digits, los píxeles van de 0 (blanco) a 16 (negro). Si dibujas con 0 y 1, el modelo podría confundirse.

# %%
#AQUI ES DONDE CARGAREMOS LA IMAGEN Y LA CONVERTIREMOS A UN ARRAY
from PIL import Image
import numpy as np

def convertir_imagen(path):
    # 1. Abrir la imagen y convertir a escala de grises ('L')
    img = Image.open(path).convert('L')

    # 2. Redimensionar a 8x8 píxeles usando un filtro de alta calidad
    img = img.resize((8, 8), Image.Resampling.LANCZOS)

    # 3. Convertir a array de numpy
    img_array = np.array(img)

    # 4. Invertir colores y escalar (0-16)
    img_array = 255 - img_array # Invertimos
    img_array = (img_array / 255.0) * 16 # Escalamos de 0-255 a 0-16

    return img_array.astype(float)


mi_digito_1 = convertir_imagen("/content/1.jpg")

mi_digito_2 = convertir_imagen("/content/2.jpg")

mi_digito_3 = convertir_imagen("/content/3.jpg")



mis_imagenes = [mi_digito_1, mi_digito_2, mi_digito_3] #los arrays de mis imagenes
etiquetas_reales = [1, 2, 3]  # numeros que dibuje

# %%
fig, axes = plt.subplots(1, 3, figsize=(12, 4))

for i, img in enumerate(mis_imagenes):
    img_flat = img.reshape(1, -1)

    res_knn = modelos["KNN (k=5)"].predict(img_flat)[0]
    res_svm = modelos["SVM (RBF)"].predict(img_flat)[0]
    res_rf = modelos["Random Forest"].predict(img_flat)[0]

    axes[i].imshow(img, cmap=plt.cm.gray_r)
    axes[i].set_title(f"Real: {etiquetas_reales[i]}\nKNN:{res_knn} | SVM:{res_svm} | RF:{res_rf}")
    axes[i].axis('off')

plt.tight_layout()
plt.show()
